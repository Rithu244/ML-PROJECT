# %% [markdown]
# **What is Unsupervised Machine Learning:-**
#     Trained by using Unlabeled data without any guidance. Type of Problem statement are clustering

# %% [markdown]
# **What is Clustering?**
#
# Clustering is a task of grouping a set of objects in such a way that objects in the same group are more similar to each other than to those in other group. K-means clustering is a widely used method for cluster analysis

# %% [markdown]
# **For Example:-**
# Imagine that you are a Data Scientist working for a retail company and your boss requests for the customers’ segmentation into the following groups: low, average, medium, or platinum customers based on spending behavior for targeted marketing purposes and product recommendations. This helps us to make better marketing strategy

# %% [markdown]
# Knowing that there is no such historical label associated with those customers, how is it possible to categorize them?
#
# This is where clustering can help. It is an unsupervised machine-learning technique used to group unlabeled data into similar categories or clusters.

# %% [markdown]
# ## What is K-Means Clustering?
# The idea behind K-means clustering is to divide a dataset into a specified number of clusters (k), where all the points within the same cluster are similar to one another, and those in different clusters are different.
#
# It starts by randomly assigning each data point to a cluster, and then it iteratively improves the clusters by moving the data points to the cluster center that is closest to them. This logic continues until the cluster assignments stop changing, or a maximum number of iterations is reached.

# %% [markdown]
# ### What are the key steps of K-means clustering?
# Below are the five main steps of the k-means algorithm:

# %% [markdown]
# 1. Specify the Number of cluster 'k'
# 2. Randomly initialize the seed or (cluster centers or centroids)
# 3. Assign each data point to the closest cluster center
# 4. Recompute the cluster's center as the mean of all data in the cluster.
# 5. Repeat steps 3 and 4 until the cluster assignment stop changing/maximum iteration is reached

# %% [markdown]
# ### Flow Chart of K-Means Clustering

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Clustering Problem

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
dataset = pd.DataFrame({'X':[2,2,5,4,8,6,5,5,6,4],'y':[4,6,6,7,3,6,2,7,3,4]})
dataset
# Out:
#    X  y
# 0  2  4
# 1  2  6
# 2  5  6
# 3  4  7
# 4  8  3
# 5  6  6
# 6  5  2
# 7  5  7
# 8  6  3
# 9  4  4

# %%
sns.scatterplot(x = dataset['X'],y = dataset['y'])
# Out:
# <Axes: xlabel='X', ylabel='y'>

# %% [markdown]
# Now will try to create random 3 cluster so we want to assign random seed point c1 = Seed Point1 = (3,5),C2 = Seed Point2 = (3,6) and C3 = Seed Point3 = (8,4)

# %%
a = []
b = []
c = []

# Seed 1
x1 = 3
y1 = 5

# Seed 2
a1 = 3
b1 = 6

# Seed 3
c1 = 8
d1 = 4

# Performing Euclidean Distance

for i in range(len(dataset.X)):
    a.append(round(np.sqrt((dataset.X[i]-x1)**2+(dataset.y[i]-y1)**2),2))
    b.append(round(np.sqrt((dataset.X[i]-a1)**2+(dataset.y[i]-b1)**2),2))
    c.append(round(np.sqrt((dataset.X[i]-c1)**2+(dataset.y[i]-d1)**2),2))

# %% [markdown]
# ### Ploting the scatterplot to visualize the datapoints along with the random cluster

# %%
sns.scatterplot(x = dataset['X'],y = dataset['y'])
plt.scatter(x1,y1,color = 'red')
plt.scatter(a1,b1,color = 'green')
plt.scatter(c1,d1,color = 'orange')

# %%
sns.scatterplot(x = dataset['X'],y = dataset['y'])
plt.scatter(x1,y1,color = 'red')
plt.scatter(a1,b1,color = 'green')
plt.scatter(c1,d1,color = 'orange')

# %%
dataset['Seed 1'] = a
dataset['Seed 2'] = b
dataset['Seed 3'] = c

# %%
dataset[['Seed 1','Seed 2','Seed 3']]
# Out:
#    Seed 1  Seed 2  Seed 3
# 0    1.41    2.24    6.00
# 1    1.41    1.00    6.32
# 2    2.24    2.00    3.61
# 3    2.24    1.41    5.00
# 4    5.39    5.83    1.00
# 5    3.16    3.00    2.83
# 6    3.61    4.47    3.61
# 7    2.83    2.24    4.24
# 8    3.61    4.24    2.24
# 9    1.41    2.24    4.00

# %%
dataset
# Out:
#    X  y  Seed 1  Seed 2  Seed 3
# 0  2  4    1.41    2.24    6.00
# 1  2  6    1.41    1.00    6.32
# 2  5  6    2.24    2.00    3.61
# 3  4  7    2.24    1.41    5.00
# 4  8  3    5.39    5.83    1.00
# 5  6  6    3.16    3.00    2.83
# 6  5  2    3.61    4.47    3.61
# 7  5  7    2.83    2.24    4.24
# 8  6  3    3.61    4.24    2.24
# 9  4  4    1.41    2.24    4.00

# %%
# Checking for less distance

for i in range(len(dataset['Seed 1'])):
    if (dataset['Seed 1'][i]<dataset['Seed 2'][i]) & (dataset['Seed 1'][i]<dataset['Seed 3'][i]):
        print(dataset['Seed 1'][i])
    elif (dataset['Seed 2'][i]<dataset['Seed 1'][i]) & (dataset['Seed 2'][i]<dataset['Seed 3'][i]):
        print(dataset['Seed 2'][i])
    else:
        print(dataset['Seed 3'][i])
# Out:
# 1.41
# 1.0
# 2.0
# 1.41
# 1.0
# 2.83
# 3.61
# 2.24
# 2.24
# 1.41

# %%
for i in range(len(dataset['Seed 1'])):
    if (dataset['Seed 1'][i]<dataset['Seed 2'][i]) & (dataset['Seed 1'][i]<dataset['Seed 3'][i]):
        print('C1')
    elif (dataset['Seed 2'][i]<dataset['Seed 1'][i]) & (dataset['Seed 2'][i]<dataset['Seed 3'][i]):
        print('C2')
    else:
        print('C3')
# Out:
# C1
# C2
# C2
# C2
# C3
# C3
# C3
# C2
# C3
# C1

# %%
Cluster_Number = []
for i in range(len(dataset['Seed 1'])):
    if (dataset['Seed 1'][i]<dataset['Seed 2'][i]) & ( dataset['Seed 1'][i]<dataset['Seed 3'][i]):
        Cluster_Number.append('C1')
    elif (dataset['Seed 2'][i]<dataset['Seed 1'][i]) & (dataset['Seed 2'][i]<dataset['Seed 3'][i]):
        Cluster_Number.append('C2')
    else:
        Cluster_Number.append('C3')

# %%
dataset['Cluster_Number'] = Cluster_Number

# %%
dataset
# Out:
#    X  y  Seed 1  Seed 2  Seed 3 Cluster_Number
# 0  2  4    1.41    2.24    6.00             C1
# 1  2  6    1.41    1.00    6.32             C2
# 2  5  6    2.24    2.00    3.61             C2
# 3  4  7    2.24    1.41    5.00             C2
# 4  8  3    5.39    5.83    1.00             C3
# 5  6  6    3.16    3.00    2.83             C3
# 6  5  2    3.61    4.47    3.61             C3
# 7  5  7    2.83    2.24    4.24             C2
# 8  6  3    3.61    4.24    2.24             C3
# 9  4  4    1.41    2.24    4.00             C1

# %%
round(dataset[dataset['Cluster_Number'] =='C1']['X'].mean(),2)
# Out:
# 3.0

# %% [markdown]
# ### updating Seed

# %%
dataset[dataset['Cluster_Number'] =='C2']['y']
# Out:
# 1    6
# 2    6
# 3    7
# 7    7
# Name: y, dtype: int64

# %%
round(dataset[dataset['Cluster_Number'] =='C2']['y'].mean(),2)
# Out:
# 6.5

# %%
# Seed 1
x1 = round(dataset[dataset['Cluster_Number'] =='C1']['X'].mean(),2)
y1 = round(dataset[dataset['Cluster_Number'] =='C1']['y'].mean(),2)

# Seed 2
a1 = round(dataset[dataset['Cluster_Number'] =='C2']['X'].mean(),2)
b1 = round(dataset[dataset['Cluster_Number'] =='C2']['y'].mean(),2)

# Seed 3
c1 = round(dataset[dataset['Cluster_Number'] =='C3']['X'].mean(),2)
d1 = round(dataset[dataset['Cluster_Number'] =='C3']['y'].mean(),2)

# %%
print(x1,y1)
print(a1,b1)
print(c1,d1)
# Out:
# 3.0 4.0
# 4.0 6.5
# 6.25 3.5

# %%
a = []
b = []
c = []


for i in range(len(dataset.X)):
    a.append(round(np.sqrt((dataset.X[i]-x1)**2+(dataset.y[i]-y1)**2),2))
    b.append(round(np.sqrt((dataset.X[i]-a1)**2+(dataset.y[i]-b1)**2),2))
    c.append(round(np.sqrt((dataset.X[i]-c1)**2+(dataset.y[i]-d1)**2),2))

# %%
a
# Out:
# [1.0, 2.24, 2.83, 3.16, 5.1, 3.61, 2.83, 3.61, 3.16, 1.0]

# %%
dataset['Seed 1'] = a
dataset['Seed 2'] = b
dataset['Seed 3'] = c

# %%
dataset[['Seed 1','Seed 2','Seed 3']]
# Out:
#    Seed 1  Seed 2  Seed 3
# 0    1.00    3.20    4.28
# 1    2.24    2.06    4.93
# 2    2.83    1.12    2.80
# 3    3.16    0.50    4.16
# 4    5.10    5.32    1.82
# 5    3.61    2.06    2.51
# 6    2.83    4.61    1.95
# 7    3.61    1.12    3.72
# 8    3.16    4.03    0.56
# 9    1.00    2.50    2.30

# %%
Cluster_Number1 = []
for i in range(len(dataset['Seed 1'])):
    if (dataset['Seed 1'][i]<dataset['Seed 2'][i]) & ( dataset['Seed 1'][i]<dataset['Seed 3'][i]):
        Cluster_Number1.append('C1')
    elif (dataset['Seed 2'][i]<dataset['Seed 1'][i]) & (dataset['Seed 2'][i]<dataset['Seed 3'][i]):
        Cluster_Number1.append('C2')
    else:
        Cluster_Number1.append('C3')

# %%
Cluster_Number1
# Out:
# ['C1', 'C2', 'C2', 'C2', 'C3', 'C2', 'C3', 'C2', 'C3', 'C1']

# %%
if (Cluster_Number1 == dataset['Cluster_Number']).sum() != 10 :
    print('Continue the same process')
else:
    print('Finaly Cluster is defined')
# Out:
# Continue the same process

# %%
Cluster_Number1 == dataset['Cluster_Number']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Cluster_Number, dtype: bool

# %%
dataset['Cluster_Number1'] = Cluster_Number1

# %%
dataset['Cluster_Number1'] == dataset['Cluster_Number']
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
dataset
# Out:
#    X  y  Seed 1  Seed 2  Seed 3 Cluster_Number Cluster_Number1
# 0  2  4    1.00    3.20    4.28             C1              C1
# 1  2  6    2.24    2.06    4.93             C2              C2
# 2  5  6    2.83    1.12    2.80             C2              C2
# 3  4  7    3.16    0.50    4.16             C2              C2
# 4  8  3    5.10    5.32    1.82             C3              C3
# 5  6  6    3.61    2.06    2.51             C3              C2
# 6  5  2    2.83    4.61    1.95             C3              C3
# 7  5  7    3.61    1.12    3.72             C2              C2
# 8  6  3    3.16    4.03    0.56             C3              C3
# 9  4  4    1.00    2.50    2.30             C1              C1

# %% [markdown]
# ### updating cluster

# %%
dataset[dataset['Cluster_Number1'] =='C2']['y']
# Out:
# 1    6
# 2    6
# 3    7
# 5    6
# 7    7
# Name: y, dtype: int64

# %%
round(dataset[dataset['Cluster_Number1'] =='C2']['y'].mean(),2)
# Out:
# 6.4

# %%
# Seed 1
x1 = round(dataset[dataset['Cluster_Number1'] =='C1']['X'].mean(),2)
y1 = round(dataset[dataset['Cluster_Number1'] =='C1']['y'].mean(),2)

# Seed 2
a1 = round(dataset[dataset['Cluster_Number1'] =='C2']['X'].mean(),2)
b1 = round(dataset[dataset['Cluster_Number1'] =='C2']['y'].mean(),2)

# Seed 3
c1 = round(dataset[dataset['Cluster_Number1'] =='C3']['X'].mean(),2)
d1 = round(dataset[dataset['Cluster_Number1'] =='C3']['y'].mean(),2)

# %%
print(x1,y1)
print(a1,b1)
print(c1,d1)
# Out:
# 3.0 4.0
# 4.4 6.4
# 6.33 2.67

# %%
a = []
b = []
c = []


for i in range(len(dataset.X)):
    a.append(round(np.sqrt((dataset.X[i]-x1)**2+(dataset.y[i]-y1)**2),2))
    b.append(round(np.sqrt((dataset.X[i]-a1)**2+(dataset.y[i]-b1)**2),2))
    c.append(round(np.sqrt((dataset.X[i]-c1)**2+(dataset.y[i]-d1)**2),2))

# %%
a
# Out:
# [1.0, 2.24, 2.83, 3.16, 5.1, 3.61, 2.83, 3.61, 3.16, 1.0]

# %%
dataset['Seed 1'] = a
dataset['Seed 2'] = b
dataset['Seed 3'] = c

# %%
dataset[['Seed 1','Seed 2','Seed 3']]
# Out:
#    Seed 1  Seed 2  Seed 3
# 0    1.00    3.39    4.53
# 1    2.24    2.43    5.46
# 2    2.83    0.72    3.59
# 3    3.16    0.72    4.92
# 4    5.10    4.95    1.70
# 5    3.61    1.65    3.35
# 6    2.83    4.44    1.49
# 7    3.61    0.85    4.53
# 8    3.16    3.76    0.47
# 9    1.00    2.43    2.68

# %%
Cluster_Number1 = []
for i in range(len(dataset['Seed 1'])):
    if (dataset['Seed 1'][i]<dataset['Seed 2'][i]) & ( dataset['Seed 1'][i]<dataset['Seed 3'][i]):
        Cluster_Number1.append('C1')
    elif (dataset['Seed 2'][i]<dataset['Seed 1'][i]) & (dataset['Seed 2'][i]<dataset['Seed 3'][i]):
        Cluster_Number1.append('C2')
    else:
        Cluster_Number1.append('C3')

# %%
Cluster_Number1
# Out:
# ['C1', 'C1', 'C2', 'C2', 'C3', 'C2', 'C3', 'C2', 'C3', 'C1']

# %%
dataset['Cluster_Number2'] = Cluster_Number1

# %%
if (dataset['Cluster_Number2'] == dataset['Cluster_Number1']).sum() != 10 :
    print('Continue the same process')
else:
    print('Finaly Cluster is defined')
# Out:
# Continue the same process

# %%
dataset['Cluster_Number2'] == dataset['Cluster_Number1']
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
dataset
# Out:
#    X  y  Seed 1  Seed 2  Seed 3 Cluster_Number Cluster_Number1 Cluster_Number2
# 0  2  4    1.00    3.39    4.53             C1              C1              C1
# 1  2  6    2.24    2.43    5.46             C2              C2              C1
# 2  5  6    2.83    0.72    3.59             C2              C2              C2
# 3  4  7    3.16    0.72    4.92             C2              C2              C2
# 4  8  3    5.10    4.95    1.70             C3              C3              C3
# 5  6  6    3.61    1.65    3.35             C3              C2              C2
# 6  5  2    2.83    4.44    1.49             C3              C3              C3
# 7  5  7    3.61    0.85    4.53             C2              C2              C2
# 8  6  3    3.16    3.76    0.47             C3              C3              C3
# 9  4  4    1.00    2.43    2.68             C1              C1              C1

# %% [markdown]
# ### updating cluster

# %%
dataset[dataset['Cluster_Number2'] =='C3']['y']
# Out:
# 4    3
# 6    2
# 8    3
# Name: y, dtype: int64

# %%
round(dataset[dataset['Cluster_Number2'] =='C3']['y'].mean(),2)
# Out:
# 2.67

# %%
# Seed 1
x1 = round(dataset[dataset['Cluster_Number2'] =='C1']['X'].mean(),2)
y1 = round(dataset[dataset['Cluster_Number2'] =='C1']['y'].mean(),2)

# Seed 2
a1 = round(dataset[dataset['Cluster_Number2'] =='C2']['X'].mean(),2)
b1 = round(dataset[dataset['Cluster_Number2'] =='C2']['y'].mean(),2)

# Seed 3
c1 = round(dataset[dataset['Cluster_Number2'] =='C3']['X'].mean(),2)
d1 = round(dataset[dataset['Cluster_Number2'] =='C3']['y'].mean(),2)

# %%
print(x1,y1)
print(a1,b1)
print(c1,d1)
# Out:
# 2.67 4.67
# 5.0 6.5
# 6.33 2.67

# %%
a = []
b = []
c = []


for i in range(len(dataset.X)):
    a.append(round(np.sqrt((dataset.X[i]-x1)**2+(dataset.y[i]-y1)**2),2))
    b.append(round(np.sqrt((dataset.X[i]-a1)**2+(dataset.y[i]-b1)**2),2))
    c.append(round(np.sqrt((dataset.X[i]-c1)**2+(dataset.y[i]-d1)**2),2))

# %%
a
# Out:
# [0.95, 1.49, 2.68, 2.68, 5.59, 3.59, 3.54, 3.3, 3.73, 1.49]

# %%
dataset['Seed 1'] = a
dataset['Seed 2'] = b
dataset['Seed 3'] = c

# %%
dataset[['Seed 1','Seed 2','Seed 3']]
# Out:
#    Seed 1  Seed 2  Seed 3
# 0    0.95    3.91    4.53
# 1    1.49    3.04    5.46
# 2    2.68    0.50    3.59
# 3    2.68    1.12    4.92
# 4    5.59    4.61    1.70
# 5    3.59    1.12    3.35
# 6    3.54    4.50    1.49
# 7    3.30    0.50    4.53
# 8    3.73    3.64    0.47
# 9    1.49    2.69    2.68

# %%
Cluster_Number1 = []
for i in range(len(dataset['Seed 1'])):
    if (dataset['Seed 1'][i]<dataset['Seed 2'][i]) & ( dataset['Seed 1'][i]<dataset['Seed 3'][i]):
        Cluster_Number1.append('C1')
    elif (dataset['Seed 2'][i]<dataset['Seed 1'][i]) & (dataset['Seed 2'][i]<dataset['Seed 3'][i]):
        Cluster_Number1.append('C2')
    else:
        Cluster_Number1.append('C3')

# %%
Cluster_Number1
# Out:
# ['C1', 'C1', 'C2', 'C2', 'C3', 'C2', 'C3', 'C2', 'C3', 'C1']

# %%
dataset['Cluster_Number3'] = Cluster_Number1

# %%
if (dataset['Cluster_Number2'] == dataset['Cluster_Number3']).sum() != 10 :
    print('Continue the same process')
else:
    print('Finaly Cluster is defined')
# Out:
# Finaly Cluster is defined

# %%
dataset['Cluster_Number2'] == dataset['Cluster_Number3']
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# dtype: bool

# %%
dataset
# Out:
#    X  y  Seed 1  Seed 2  Seed 3 Cluster_Number Cluster_Number1  \
# 0  2  4    0.95    3.91    4.53             C1              C1
# 1  2  6    1.49    3.04    5.46             C2              C2
# 2  5  6    2.68    0.50    3.59             C2              C2
# 3  4  7    2.68    1.12    4.92             C2              C2
# 4  8  3    5.59    4.61    1.70             C3              C3
# 5  6  6    3.59    1.12    3.35             C3              C2
# 6  5  2    3.54    4.50    1.49             C3              C3
# 7  5  7    3.30    0.50    4.53             C2              C2
# 8  6  3    3.73    3.64    0.47             C3              C3
# 9  4  4    1.49    2.69    2.68             C1              C1
#
#   Cluster_Number2 Cluster_Number3
# 0              C1              C1
# 1              C1              C1
# 2              C2              C2
# 3              C2              C2
# 4              C3              C3
# 5              C2              C2
# ...

# %% [markdown]
# ### No movement of data Points Hence these are the final position

# %%
sns.scatterplot(x = dataset['X'],y = dataset['y'],hue = dataset['Cluster_Number3'])
plt.scatter(x1,y1,color = 'blue',s = 100,marker = '*')
plt.scatter(a1,b1,color = 'orange',s = 100,marker = '*')
plt.scatter(c1,d1,color = 'green',s = 100,marker = '*')

# %% [markdown]
# ### Now you understood how k-means work manualy

# %% [markdown]
# ---------------------------------------------- Using Sklearn ---------------------------------------------------------------

# %% [markdown]
# ### Now will perform the same using Sklearn library

# %% [markdown]
# ### Now will perform the same using Sklearn library

# %%
dataset = pd.DataFrame({'X': [2, 2, 5, 4, 8, 6, 5, 5, 6, 4], 'y': [4, 6, 6, 7, 3, 6, 2, 7, 3, 4]})
dataset
# Out:
#    X  y
# 0  2  4
# 1  2  6
# 2  5  6
# 3  4  7
# 4  8  3
# 5  6  6
# 6  5  2
# 7  5  7
# 8  6  3
# 9  4  4

# %%
# !pip install --upgrade scikit-learn

# %%
#!pip install --upgrade threadpoolctl

# %%
# !conda create --name myenv python=3.8
# !conda activate myenv
# !pip install scikit-learn
# !conda update --all

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Create the dataset
dataset = pd.DataFrame({'X': [2, 2, 5, 4, 8, 6, 5, 5, 6, 4], 'y': [4, 6, 6, 7, 3, 6, 2, 7, 3, 4]})

# Initialize the KMeans model with k=3
kmeans = KMeans(n_clusters=3)

# Fit the model to the data
kmeans.fit(dataset)

# Add the cluster labels to the DataFrame
dataset['Cluster'] = kmeans.labels_

# Print the DataFrame with cluster labels
print(dataset)

# Plot the data points with cluster centers
plt.scatter(dataset['X'], dataset['y'], c=dataset['Cluster'], cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='black', marker='x', s=200)
plt.xlabel('X')
plt.ylabel('y')
plt.title('K-Means Clustering (k=3)')
plt.show()
# Out:
#    X  y  Cluster
# 0  2  4        2
# 1  2  6        2
# 2  5  6        1
# 3  4  7        1
# 4  8  3        0
# 5  6  6        1
# 6  5  2        0
# 7  5  7        1
# 8  6  3        0
# 9  4  4        2

# %% [markdown]
# ### Choosing the optimum number of clusters

# %% [markdown]
# ### Determine the best number of cluster
# A clustering model will not be relevant if we fail to identify the correct number of clusters to consider. Multiple techniques exist in the literature. We are going to consider the Elbow method, one of the widely used to find the optimal number of clusters.
#
# The first helper function creates for each value of K the corresponding KMeans model and saves its inertia along with the actual K value.
#
# The second function uses those inertias and K values to generate the final Elbow plot.

# %% [markdown]
# ### **WCSS** --> [Within Cluster Sum of Squares]

# %%
# Now will find the wcss value for different number of cluster

wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(dataset[['X','y']])

    wcss.append(kmeans.inertia_)

# %%
# Now will plot the elbow graph to select optimal value of cluster

plt.plot(range(1,11),wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('No of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# #### So we can see there is a sudden drop when the No of cluster is 3, and after that there is no significant drop, so we are considering the optimal value of cluster(k) = 3

# %%
dataset
# Out:
#    X  y  Cluster
# 0  2  4        2
# 1  2  6        2
# 2  5  6        1
# 3  4  7        1
# 4  8  3        0
# 5  6  6        1
# 6  5  2        0
# 7  5  7        1
# 8  6  3        0
# 9  4  4        2

# %% [markdown]
# ### silhouette score
#
# The silhouette score is a measure of the quality of the clusters formed by a clustering algorithm, It explains how well the data is clusters and separated, The silhouette score ranges from -1 to 1, with higher values indicating better cluster separation and cohesion

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(dataset[['X', 'y']], dataset['Cluster'].values)
print(f"Silhouette Score (Using scikit-learn): {silhouette_avg}")
# Out:
# Silhouette Score (Using scikit-learn): 0.45361570171210025

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(dataset[['X', 'y']])

    # Check the number of unique labels
    unique_labels = np.unique(labels)
    if len(unique_labels) > 1 and len(unique_labels) < len(dataset):
        silhouette_avg = silhouette_score(dataset[['X', 'y']], labels, metric='euclidean')
        silhouette_scores.append(silhouette_avg)
    else:
        # Handle the case where the number of unique labels is not valid
        silhouette_scores.append(None)

plt.figure(figsize=(14, 7))
plt.plot(range(2, 11), silhouette_scores, marker='*')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score Method')
plt.show()

# %% [markdown]
# #### Based on the silhouette scores calculated for different values of k (number of clusters), it has been observed that the optimal number of clusters is 3
